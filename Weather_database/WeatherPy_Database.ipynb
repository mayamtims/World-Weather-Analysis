# %%
#Import dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
#Import citipy
from citipy import citipy

# %%
#Create a list holding the cities
cities = []

#Identify the nearest city for each latitiude and longitude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 750

# %%
#Create an empty list to hold weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

#Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    #If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
#Indicate the Data Loading is complete
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | san julian
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | garissa
# Processing Record 6 of Set 1 | beringovskiy
# Processing Record 7 of Set 1 | rezekne
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | alice springs
# Processing Record 14 of Set 1 | chapais
# Processing Record 15 of Set 1 | nanortalik
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | karratha
# Processing Record 20 of Set 1 | asfi
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | mukhen
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | oinoi
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | galesong
# Processing Record 30 of Set 1 | ixtapa
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | elk plain
# Processing Record 33 of Set 1 | mount isa
# Processing Record 34 of Set 1 | king city
# Processing Record 35 of Set 1 | saint-vallier
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | keti bandar
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | thinadhoo
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | gitarama
# Processing Record 44 of Set 1 | ponerihouen
# Processing Record 45 of Set 1 | am timan
# Processing Record 46 of Set 1 | ostrovnoy
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | saint-joseph
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 2 | hirara
# Processing Record 5 of Set 2 | anadyr
# Processing Record 6 of Set 2 | batangafo
# Processing Record 7 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 2 | ayan
# Processing Record 9 of Set 2 | kampot
# Processing Record 10 of Set 2 | ossora
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | nabire
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | burnie
# Processing Record 15 of Set 2 | chake chake
# Processing Record 16 of Set 2 | poltava
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | changtu
# Processing Record 21 of Set 2 | kloulklubed
# Processing Record 22 of Set 2 | iberia
# Processing Record 23 of Set 2 | nishihara
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | boulder
# Processing Record 26 of Set 2 | price
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | claremore
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | hami
# Processing Record 32 of Set 2 | alyangula
# Processing Record 33 of Set 2 | balkanabat
# Processing Record 34 of Set 2 | klaksvik
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | sorong
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | acapulco
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | pudozh
# Processing Record 43 of Set 2 | tshikapa
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | araouane
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | mount gambier
# Processing Record 49 of Set 2 | conceicao do araguaia
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | ballina
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | okakarara
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | constitucion
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | dingle
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | kirensk
# Processing Record 11 of Set 3 | sola
# Processing Record 12 of Set 3 | almeirim
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | vanavara
# Processing Record 15 of Set 3 | kununurra
# Processing Record 16 of Set 3 | athabasca
# Processing Record 17 of Set 3 | karasjok
# Processing Record 18 of Set 3 | kudchi
# City not found. Skipping...
# Processing Record 19 of Set 3 | cleethorpes
# Processing Record 20 of Set 3 | ushuaia
# Processing Record 21 of Set 3 | launceston
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | bilma
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | samarai
# Processing Record 26 of Set 3 | mumbwa
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | ginir
# Processing Record 29 of Set 3 | ihosy
# Processing Record 30 of Set 3 | severnoye
# Processing Record 31 of Set 3 | dicabisagan
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | portland
# Processing Record 34 of Set 3 | mykolayiv
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | phrai bung
# City not found. Skipping...
# Processing Record 37 of Set 3 | yurimaguas
# Processing Record 38 of Set 3 | turan
# Processing Record 39 of Set 3 | fayetteville
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | damaturu
# Processing Record 44 of Set 3 | diffa
# Processing Record 45 of Set 3 | kapustin yar-1
# City not found. Skipping...
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | muli
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | malakal
# Processing Record 4 of Set 4 | mach
# Processing Record 5 of Set 4 | roebourne
# Processing Record 6 of Set 4 | lewistown
# Processing Record 7 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 8 of Set 4 | cayenne
# Processing Record 9 of Set 4 | ipu
# Processing Record 10 of Set 4 | nuuk
# Processing Record 11 of Set 4 | humpolec
# Processing Record 12 of Set 4 | matara
# Processing Record 13 of Set 4 | san policarpo
# Processing Record 14 of Set 4 | plouzane
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | le port
# Processing Record 17 of Set 4 | port moresby
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | yar-sale
# Processing Record 20 of Set 4 | siavonga
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | kuching
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | sanchursk
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | marawi
# Processing Record 31 of Set 4 | labuhan
# Processing Record 32 of Set 4 | gat
# Processing Record 33 of Set 4 | mabay
# Processing Record 34 of Set 4 | utiel
# Processing Record 35 of Set 4 | west bay
# Processing Record 36 of Set 4 | sokoni
# Processing Record 37 of Set 4 | nieuwpoort
# Processing Record 38 of Set 4 | bridlington
# Processing Record 39 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 4 | outjo
# Processing Record 41 of Set 4 | wicklow
# Processing Record 42 of Set 4 | emerald
# Processing Record 43 of Set 4 | puerto ayora
# Processing Record 44 of Set 4 | winchester
# Processing Record 45 of Set 4 | santa maria
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | thompson
# Processing Record 48 of Set 4 | vila
# Processing Record 49 of Set 4 | puerto madryn
# Processing Record 50 of Set 4 | naberera
# Processing Record 1 of Set 5 | sandnessjoen
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | lensk
# Processing Record 4 of Set 5 | brae
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | margate
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | haines junction
# Processing Record 11 of Set 5 | laguna
# Processing Record 12 of Set 5 | fare
# Processing Record 13 of Set 5 | mwingi
# Processing Record 14 of Set 5 | benguela
# Processing Record 15 of Set 5 | namibe
# Processing Record 16 of Set 5 | adrar
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | morondava
# Processing Record 19 of Set 5 | royan
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | estacion coahuila
# Processing Record 22 of Set 5 | aitape
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | pasighat
# Processing Record 27 of Set 5 | port antonio
# Processing Record 28 of Set 5 | ville-marie
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | barentu
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | gao
# Processing Record 37 of Set 5 | kidal
# Processing Record 38 of Set 5 | alta floresta
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | vaitape
# Processing Record 41 of Set 5 | ankara
# Processing Record 42 of Set 5 | umm lajj
# Processing Record 43 of Set 5 | lincoln
# Processing Record 44 of Set 5 | rafraf
# Processing Record 45 of Set 5 | mana
# Processing Record 46 of Set 5 | ilulissat
# Processing Record 47 of Set 5 | makarov
# Processing Record 48 of Set 5 | tiarei
# Processing Record 49 of Set 5 | prainha
# Processing Record 50 of Set 5 | talnakh
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | hilo
# Processing Record 3 of Set 6 | kuhestan
# City not found. Skipping...
# Processing Record 4 of Set 6 | eagle pass
# Processing Record 5 of Set 6 | omboue
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | manaus
# Processing Record 8 of Set 6 | kajaani
# Processing Record 9 of Set 6 | sarkand
# Processing Record 10 of Set 6 | sisophon
# Processing Record 11 of Set 6 | maba
# Processing Record 12 of Set 6 | pakwach
# City not found. Skipping...
# Processing Record 13 of Set 6 | deputatskiy
# Processing Record 14 of Set 6 | solnechnyy
# Processing Record 15 of Set 6 | leh
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | veraval
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | krasnoznamensk
# Processing Record 20 of Set 6 | nouadhibou
# Processing Record 21 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | forestville
# Processing Record 24 of Set 6 | balabac
# Processing Record 25 of Set 6 | korla
# Processing Record 26 of Set 6 | kang
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | ferme-neuve
# Processing Record 29 of Set 6 | saurimo
# Processing Record 30 of Set 6 | westport
# Processing Record 31 of Set 6 | aripuana
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | juan aldama
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | tabuk
# Processing Record 36 of Set 6 | te anau
# Processing Record 37 of Set 6 | belgaum
# Processing Record 38 of Set 6 | kenai
# Processing Record 39 of Set 6 | shar
# Processing Record 40 of Set 6 | vasto
# Processing Record 41 of Set 6 | adre
# Processing Record 42 of Set 6 | ha giang
# Processing Record 43 of Set 6 | cantagallo
# Processing Record 44 of Set 6 | lata
# Processing Record 45 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 6 | dori
# Processing Record 47 of Set 6 | hay river
# Processing Record 48 of Set 6 | basco
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | pochutla
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | jiroft
# City not found. Skipping...
# Processing Record 3 of Set 7 | ambon
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | bandiagara
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | coquimbo
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | joshimath
# Processing Record 10 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 7 | poya
# Processing Record 12 of Set 7 | harbour breton
# Processing Record 13 of Set 7 | murray bridge
# Processing Record 14 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 7 | kushnarenkovo
# Processing Record 16 of Set 7 | nakhon thai
# Processing Record 17 of Set 7 | saldanha
# Processing Record 18 of Set 7 | saint-augustin
# Processing Record 19 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 7 | codrington
# Processing Record 21 of Set 7 | homer
# Processing Record 22 of Set 7 | kayes
# Processing Record 23 of Set 7 | odweyne
# Processing Record 24 of Set 7 | anchorage
# Processing Record 25 of Set 7 | quelimane
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | flagstaff
# Processing Record 28 of Set 7 | kurilsk
# Processing Record 29 of Set 7 | moron
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | banikoara
# Processing Record 32 of Set 7 | rumburk
# Processing Record 33 of Set 7 | itarema
# Processing Record 34 of Set 7 | palmer
# Processing Record 35 of Set 7 | kodinsk
# Processing Record 36 of Set 7 | mahibadhoo
# Processing Record 37 of Set 7 | bila
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | altay
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | smoky lake
# Processing Record 42 of Set 7 | ures
# Processing Record 43 of Set 7 | fairview
# Processing Record 44 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 7 | puerto del rosario
# Processing Record 46 of Set 7 | kalmunai
# Processing Record 47 of Set 7 | saint-georges
# Processing Record 48 of Set 7 | bulawayo
# Processing Record 49 of Set 7 | garmsar
# Processing Record 50 of Set 7 | richards bay
# Processing Record 1 of Set 8 | ayame
# Processing Record 2 of Set 8 | nizhniy tsasuchey
# Processing Record 3 of Set 8 | sarany
# Processing Record 4 of Set 8 | makung
# City not found. Skipping...
# Processing Record 5 of Set 8 | flinders
# Processing Record 6 of Set 8 | chulym
# Processing Record 7 of Set 8 | los llanos de aridane
# Processing Record 8 of Set 8 | yamada
# Processing Record 9 of Set 8 | shirokiy
# Processing Record 10 of Set 8 | yulara
# Processing Record 11 of Set 8 | zolochiv
# Processing Record 12 of Set 8 | tir pol
# City not found. Skipping...
# Processing Record 13 of Set 8 | port lincoln
# Processing Record 14 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 8 | vyazemskiy
# Processing Record 16 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 8 | bardiyah
# Processing Record 18 of Set 8 | port-gentil
# Processing Record 19 of Set 8 | palamos
# Processing Record 20 of Set 8 | asau
# Processing Record 21 of Set 8 | karoi
# Processing Record 22 of Set 8 | fairbanks
# Processing Record 23 of Set 8 | murgab
# Processing Record 24 of Set 8 | mocuba
# Processing Record 25 of Set 8 | amli
# Processing Record 26 of Set 8 | tabou
# Processing Record 27 of Set 8 | goderich
# Processing Record 28 of Set 8 | seoul
# Processing Record 29 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 30 of Set 8 | ugoofaaru
# Processing Record 31 of Set 8 | lazarev
# Processing Record 32 of Set 8 | tuatapere
# Processing Record 33 of Set 8 | cangucu
# Processing Record 34 of Set 8 | norrtalje
# Processing Record 35 of Set 8 | plettenberg bay
# Processing Record 36 of Set 8 | aykhal
# Processing Record 37 of Set 8 | bambous virieux
# Processing Record 38 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 39 of Set 8 | san martin jilotepeque
# Processing Record 40 of Set 8 | tomatlan
# Processing Record 41 of Set 8 | ardmore
# Processing Record 42 of Set 8 | el cobre
# Processing Record 43 of Set 8 | kapuskasing
# Processing Record 44 of Set 8 | road town
# Processing Record 45 of Set 8 | praia
# Processing Record 46 of Set 8 | vitimskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | greenwood
# Processing Record 48 of Set 8 | albania
# Processing Record 49 of Set 8 | mangrol
# Processing Record 50 of Set 8 | berga
# Processing Record 1 of Set 9 | arkhangelsk
# Processing Record 2 of Set 9 | chirongui
# Processing Record 3 of Set 9 | okha
# Processing Record 4 of Set 9 | beckley
# Processing Record 5 of Set 9 | srednekolymsk
# Processing Record 6 of Set 9 | atar
# Processing Record 7 of Set 9 | victoria
# Processing Record 8 of Set 9 | isangel
# Processing Record 9 of Set 9 | saint george
# Processing Record 10 of Set 9 | beatrice
# Processing Record 11 of Set 9 | ulkan
# Processing Record 12 of Set 9 | nizhnevartovsk
# Processing Record 13 of Set 9 | ciudad real
# Processing Record 14 of Set 9 | batagay-alyta
# Processing Record 15 of Set 9 | wanning
# Processing Record 16 of Set 9 | san quintin
# Processing Record 17 of Set 9 | haicheng
# Processing Record 18 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 9 | telfs
# Processing Record 20 of Set 9 | dukat
# Processing Record 21 of Set 9 | saryagash
# Processing Record 22 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 9 | gushikawa
# Processing Record 24 of Set 9 | caravelas
# Processing Record 25 of Set 9 | topchikha
# Processing Record 26 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 27 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 9 | fallon
# Processing Record 29 of Set 9 | knyaze-volkonskoye
# Processing Record 30 of Set 9 | chandrakona
# Processing Record 31 of Set 9 | beyneu
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | guerrero negro
# Processing Record 34 of Set 9 | ketchenery
# City not found. Skipping...
# Processing Record 35 of Set 9 | ouango
# Processing Record 36 of Set 9 | mineros
# Processing Record 37 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 9 | oksbol
# Processing Record 39 of Set 9 | avera
# Processing Record 40 of Set 9 | metehara
# City not found. Skipping...
# Processing Record 41 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 42 of Set 9 | vostok
# Processing Record 43 of Set 9 | hambantota
# Processing Record 44 of Set 9 | tarko-sale
# Processing Record 45 of Set 9 | obera
# Processing Record 46 of Set 9 | huntsville
# Processing Record 47 of Set 9 | teguise
# Processing Record 48 of Set 9 | coro
# Processing Record 49 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 50 of Set 9 | solikamsk
# Processing Record 1 of Set 10 | taltal
# Processing Record 2 of Set 10 | mathbaria
# Processing Record 3 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 10 | tura
# Processing Record 6 of Set 10 | shitanjing
# Processing Record 7 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 10 | bijie
# Processing Record 9 of Set 10 | amparafaravola
# Processing Record 10 of Set 10 | los corrales de buelna
# Processing Record 11 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 10 | hagerstown
# Processing Record 13 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 10 | ketchikan
# Processing Record 16 of Set 10 | rajapur
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | samur
# Processing Record 19 of Set 10 | pundaguitan
# Processing Record 20 of Set 10 | ndola
# Processing Record 21 of Set 10 | eastlake
# Processing Record 22 of Set 10 | sembe
# Processing Record 23 of Set 10 | honningsvag
# Processing Record 24 of Set 10 | buloh kasap
# Processing Record 25 of Set 10 | meihekou
# Processing Record 26 of Set 10 | ventspils
# Processing Record 27 of Set 10 | kutum
# Processing Record 28 of Set 10 | jiblah
# Processing Record 29 of Set 10 | kudahuvadhoo
# Processing Record 30 of Set 10 | mumford
# Processing Record 31 of Set 10 | walvis bay
# Processing Record 32 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 10 | san cristobal
# Processing Record 34 of Set 10 | comodoro rivadavia
# Processing Record 35 of Set 10 | abu samrah
# Processing Record 36 of Set 10 | okato
# Processing Record 37 of Set 10 | oriximina
# Processing Record 38 of Set 10 | mayumba
# Processing Record 39 of Set 10 | touros
# Processing Record 40 of Set 10 | hasaki
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | hamilton
# Processing Record 43 of Set 10 | havelock
# Processing Record 44 of Set 10 | bosanska dubica
# Processing Record 45 of Set 10 | inzer
# Processing Record 46 of Set 10 | konibodom
# Processing Record 47 of Set 10 | amuntai
# Processing Record 48 of Set 10 | itupiranga
# Processing Record 49 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 50 of Set 10 | ola
# Processing Record 1 of Set 11 | pringsewu
# Processing Record 2 of Set 11 | rehoboth
# Processing Record 3 of Set 11 | channel-port aux basques
# Processing Record 4 of Set 11 | esperance
# Processing Record 5 of Set 11 | hadgaon
# Processing Record 6 of Set 11 | kosonsoy
# Processing Record 7 of Set 11 | mareeba
# Processing Record 8 of Set 11 | tinskoy
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | kisangani
# Processing Record 11 of Set 11 | kibuye
# Processing Record 12 of Set 11 | carlsbad
# Processing Record 13 of Set 11 | vallenar
# Processing Record 14 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | ryotsu
# Processing Record 16 of Set 11 | santa cruz de la palma
# Processing Record 17 of Set 11 | yurgamysh
# Processing Record 18 of Set 11 | golden
# Processing Record 19 of Set 11 | senador guiomard
# Processing Record 20 of Set 11 | san pedro
# Processing Record 21 of Set 11 | apastepeque
# Processing Record 22 of Set 11 | yichun
# Processing Record 23 of Set 11 | areia branca
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 26 of Set 11 | acajutla
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | amahai
# Processing Record 29 of Set 11 | beloha
# Processing Record 30 of Set 11 | knysna
# Processing Record 31 of Set 11 | bogorodskoye
# Processing Record 32 of Set 11 | little current
# Processing Record 33 of Set 11 | elat
# Processing Record 34 of Set 11 | sulecin
# Processing Record 35 of Set 11 | devonport
# Processing Record 36 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 11 | pacific grove
# Processing Record 38 of Set 11 | ouadda
# Processing Record 39 of Set 11 | taoudenni
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | yafran
# Processing Record 42 of Set 11 | atambua
# Processing Record 43 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 11 | dumabato
# Processing Record 45 of Set 11 | meulaboh
# Processing Record 46 of Set 11 | nizhniy kuranakh
# Processing Record 47 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 11 | pangkalanbuun
# Processing Record 49 of Set 11 | college
# Processing Record 50 of Set 11 | kaohsiung
# Processing Record 1 of Set 12 | bojaya
# City not found. Skipping...
# Processing Record 2 of Set 12 | hobyo
# Processing Record 3 of Set 12 | davenport
# Processing Record 4 of Set 12 | sukumo
# Processing Record 5 of Set 12 | litovko
# Processing Record 6 of Set 12 | aleksandrovskoye
# Processing Record 7 of Set 12 | redmond
# Processing Record 8 of Set 12 | aksu
# Processing Record 9 of Set 12 | upata
# Processing Record 10 of Set 12 | maloy
# Processing Record 11 of Set 12 | aberdeen
# Processing Record 12 of Set 12 | vila velha
# Processing Record 13 of Set 12 | nhulunbuy
# Processing Record 14 of Set 12 | thung song
# Processing Record 15 of Set 12 | petropavlovka
# Processing Record 16 of Set 12 | maqrin
# City not found. Skipping...
# Processing Record 17 of Set 12 | loukhi
# Processing Record 18 of Set 12 | merced
# Processing Record 19 of Set 12 | diamantino
# Processing Record 20 of Set 12 | vao
# Processing Record 21 of Set 12 | boras
# Processing Record 22 of Set 12 | riverton
# Processing Record 23 of Set 12 | amga
# Processing Record 24 of Set 12 | bonavista
# Processing Record 25 of Set 12 | asyut
# Processing Record 26 of Set 12 | grand gaube
# Processing Record 27 of Set 12 | handia
# Processing Record 28 of Set 12 | parakou
# Processing Record 29 of Set 12 | teya
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | sabha
# Processing Record 32 of Set 12 | barberton
# Processing Record 33 of Set 12 | nuristan
# Processing Record 34 of Set 12 | sakakah
# Processing Record 35 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 12 | sergeyevka
# Processing Record 37 of Set 12 | faya
# Processing Record 38 of Set 12 | sungairaya
# Processing Record 39 of Set 12 | kurashiki
# Processing Record 40 of Set 12 | barbatesti
# Processing Record 41 of Set 12 | monrovia
# Processing Record 42 of Set 12 | kavaratti
# Processing Record 43 of Set 12 | machaneng
# Processing Record 44 of Set 12 | altagracia de orituco
# Processing Record 45 of Set 12 | la palma del condado
# Processing Record 46 of Set 12 | dongsheng
# Processing Record 47 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 12 | goya
# Processing Record 49 of Set 12 | atikokan
# Processing Record 50 of Set 12 | tevriz
# Processing Record 1 of Set 13 | shushenskoye
# Processing Record 2 of Set 13 | menongue
# Processing Record 3 of Set 13 | mildura
# Processing Record 4 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 13 | datong
# Processing Record 6 of Set 13 | sept-iles
# Processing Record 7 of Set 13 | viesca
# Processing Record 8 of Set 13 | mineiros
# Processing Record 9 of Set 13 | leavenworth
# Processing Record 10 of Set 13 | guamuchil
# Processing Record 11 of Set 13 | waingapu
# Processing Record 12 of Set 13 | nuevo progreso
# Processing Record 13 of Set 13 | salani
# Processing Record 14 of Set 13 | komsomolskiy
# Processing Record 15 of Set 13 | santa rosa
# Processing Record 16 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 13 | burica
# City not found. Skipping...
# Processing Record 18 of Set 13 | ushumun
# Processing Record 19 of Set 13 | banjar
# Processing Record 20 of Set 13 | skibbereen
# Processing Record 21 of Set 13 | dryden
# Processing Record 22 of Set 13 | bosaso
# Processing Record 23 of Set 13 | gravdal
# Processing Record 24 of Set 13 | koumac
# Processing Record 25 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 13 | puerto colombia
# Processing Record 27 of Set 13 | sisimiut
# Processing Record 28 of Set 13 | amnat charoen
# Processing Record 29 of Set 13 | inuvik
# Processing Record 30 of Set 13 | panguna
# Processing Record 31 of Set 13 | rocha
# Processing Record 32 of Set 13 | mehamn
# Processing Record 33 of Set 13 | oranjemund
# Processing Record 34 of Set 13 | zhigansk
# Processing Record 35 of Set 13 | waddan
# Processing Record 36 of Set 13 | tessalit
# Processing Record 37 of Set 13 | lhokseumawe
# Processing Record 38 of Set 13 | udachnyy
# Processing Record 39 of Set 13 | mekhelta
# City not found. Skipping...
# Processing Record 40 of Set 13 | micheweni
# Processing Record 41 of Set 13 | ustupo
# Processing Record 42 of Set 13 | nemuro
# Processing Record 43 of Set 13 | doha
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | seymchan
# Processing Record 46 of Set 13 | abu kamal
# Processing Record 47 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 13 | huarmey
# Processing Record 49 of Set 13 | tazovskiy
# Processing Record 50 of Set 13 | kamenka
# Processing Record 1 of Set 14 | kohtla-jarve
# Processing Record 2 of Set 14 | maues
# Processing Record 3 of Set 14 | qaqortoq
# Processing Record 4 of Set 14 | kiruna
# Processing Record 5 of Set 14 | semikarakorsk
# Processing Record 6 of Set 14 | ponta delgada
# Processing Record 7 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 14 | naryan-mar
# Processing Record 9 of Set 14 | jalu
# Processing Record 10 of Set 14 | tigre
# Processing Record 11 of Set 14 | yumen
# Processing Record 12 of Set 14 | mokhsogollokh
# Processing Record 13 of Set 14 | noumea
# Processing Record 14 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 14 | san
# Processing Record 16 of Set 14 | kjopsvik
# Processing Record 17 of Set 14 | bud
# Processing Record 18 of Set 14 | victor harbor
# Processing Record 19 of Set 14 | ylivieska
# Processing Record 20 of Set 14 | high level
# Processing Record 21 of Set 14 | valentin gomez farias
# Processing Record 22 of Set 14 | mayo
# Processing Record 23 of Set 14 | marsaxlokk
# Processing Record 24 of Set 14 | novouzensk
# Processing Record 25 of Set 14 | sao joao da barra
# Processing Record 26 of Set 14 | vilcun
# Processing Record 27 of Set 14 | orlik
# Processing Record 28 of Set 14 | ziyamet
# City not found. Skipping...
# Processing Record 29 of Set 14 | wolfeboro
# Processing Record 30 of Set 14 | rameswaram
# Processing Record 31 of Set 14 | luderitz
# Processing Record 32 of Set 14 | santa cruz
# Processing Record 33 of Set 14 | mpika
# Processing Record 34 of Set 14 | riyadh
# Processing Record 35 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 36 of Set 14 | sorso
# Processing Record 37 of Set 14 | brazzaville
# Processing Record 38 of Set 14 | aguimes
# Processing Record 39 of Set 14 | melbu
# Processing Record 40 of Set 14 | miyako
# Processing Record 41 of Set 14 | mayuge
# Processing Record 42 of Set 14 | mackay
# Processing Record 43 of Set 14 | huambo
# Processing Record 44 of Set 14 | toropets
# Processing Record 45 of Set 14 | roald
# Processing Record 46 of Set 14 | raga
# Processing Record 47 of Set 14 | severnyy
# Processing Record 48 of Set 14 | tomohon
# Processing Record 49 of Set 14 | mitsamiouli
# Processing Record 50 of Set 14 | ginda
# Processing Record 1 of Set 15 | svatove
# Processing Record 2 of Set 15 | liusha
# Processing Record 3 of Set 15 | paamiut
# Processing Record 4 of Set 15 | wamba
# Processing Record 5 of Set 15 | fort nelson
# Processing Record 6 of Set 15 | ciudad bolivar
# Processing Record 7 of Set 15 | izhma
# Processing Record 8 of Set 15 | sovetsk
# Processing Record 9 of Set 15 | okhotsk
# Processing Record 10 of Set 15 | christchurch
# Processing Record 11 of Set 15 | formosa do rio preto
# Processing Record 12 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 13 of Set 15 | sarakhs
# Processing Record 14 of Set 15 | brigantine
# Processing Record 15 of Set 15 | vechta
# Processing Record 16 of Set 15 | kozhevnikovo
# Processing Record 17 of Set 15 | arslev
# Processing Record 18 of Set 15 | kundiawa
# Processing Record 19 of Set 15 | russell
# Processing Record 20 of Set 15 | chimbote
# Processing Record 21 of Set 15 | algiers
# Processing Record 22 of Set 15 | la ronge
# Processing Record 23 of Set 15 | macau
# Processing Record 24 of Set 15 | awash
# Processing Record 25 of Set 15 | nantucket
# Processing Record 26 of Set 15 | north bend
# Processing Record 27 of Set 15 | saint anthony
# Processing Record 28 of Set 15 | cukai
# Processing Record 29 of Set 15 | wasilla
# Processing Record 30 of Set 15 | masyaf
# Processing Record 31 of Set 15 | egvekinot
# Processing Record 32 of Set 15 | ust-ilimsk
# Processing Record 33 of Set 15 | maymyo
# Processing Record 34 of Set 15 | akdepe
# Processing Record 35 of Set 15 | port hedland
# Processing Record 36 of Set 15 | belogorsk
# Processing Record 37 of Set 15 | peace river
# Processing Record 38 of Set 15 | itauna
# Processing Record 39 of Set 15 | byron bay
# Processing Record 40 of Set 15 | ancud
# Processing Record 41 of Set 15 | port keats
# Processing Record 42 of Set 15 | carauari
# Processing Record 43 of Set 15 | sao gabriel da cachoeira
# Processing Record 44 of Set 15 | canton
# Processing Record 45 of Set 15 | buraydah
# Processing Record 46 of Set 15 | zhigalovo
# Processing Record 47 of Set 15 | pampas
# Processing Record 48 of Set 15 | abashiri
# Processing Record 49 of Set 15 | starkville
# Processing Record 50 of Set 15 | khawhai
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bluff      NZ -46.6000  168.3333     55.53        68          96
# 1    San Julian      MX  21.0167 -102.1667     68.02        47          68
# 2     Upernavik      GL  72.7868  -56.1549     29.95        97         100
# 3      Souillac      MU -20.5167   57.5167     71.98        83          40
# 4       Garissa      KE  -0.4536   39.6401     79.18        71          74
# ..          ...     ...      ...       ...       ...       ...         ...
# 671   Zhigalovo      RU  54.8097  105.1578     27.57        91          99
# 672      Pampas      PE -12.4000  -74.9000     55.11        77          77
# 673    Abashiri      JP  44.0213  144.2697     48.94        88          79
# 674  Starkville      US  33.4504  -88.8184     69.46        66           1
# 675     Khawhai      IN  23.3667   93.1167     53.33        98          77
#
#      Wind Speed Current Description
# 0         27.02     overcast clouds
# 1          7.14       broken clouds
# 2         16.11                snow
# 3          3.44    scattered clouds
# 4         13.31       broken clouds
# ..          ...                 ...
# 671        3.91     overcast clouds
# 672        6.67       broken clouds
# 673        7.70       broken clouds
# 674        0.00           clear sky
# 675        1.10       broken clouds
#
# [676 rows x 9 columns]

# %%
#Create output file (CSV)
output_data_file = "Weather_database/WeatherPy_database.csv"
#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
